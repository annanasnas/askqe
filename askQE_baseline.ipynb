# %%
# Например, перемещаем ноутбук в папку репо
# !mv "/content/drive/MyDrive/Colab Notebooks/askQE_baseline.ipynb" "/content/askqe/askQE_baseline.ipynb"
# Out:
# mv: cannot stat '/content/drive/MyDrive/Colab Notebooks/askQE_baseline.ipynb': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
